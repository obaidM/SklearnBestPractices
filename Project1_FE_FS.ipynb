# %% [markdown]
# # Best practices for the project

# %% [markdown]
# # ---------------- Feature engineering-------------------------###

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

## Sklearn 
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline

###### feature engineering packages
from feature_engine import missing_data_imputers as mdi
from feature_engine import discretisers as dsc
from feature_engine import categorical_encoders as ce
from feature_engine.categorical_encoders import WoERatioCategoricalEncoder
from feature_engine.discretisers import DecisionTreeDiscretiser
from feature_engine.outlier_removers import Winsorizer

######## Feature selection packages 

from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor


#### model selection 
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
data = pd.read_csv('exercise_03_train.csv' )

# %%
data.shape
# Out:
# (40000, 101)

# %%
data['x41'] = data['x41'].astype(str)
data['x41'] = data['x41'].apply(lambda x: x.strip('$'))
data['x41']= data['x41'].astype(float)

data['x41'].mean()
# Out:
# -3.2865869880482257

# %%
##### capture the type of each 
### numeric feature with less than 5 unique values is probably discrete 9 integers and not numeric
discrete= [ var for var in data.columns   if data[var].dtype != 'O' and var!='y' and data[var].nunique() < 5 ]
contin= [ var for var in data.columns     if data[var].dtype != 'O' and var!='y' and var not in discrete]
categorical = [var for var in data.columns if data[var].dtype =='O']


print("there are {} discrete features".format(len(discrete)))
print("there are {} continous or numeric features".format(len(contin)))
print("there are {} categorical features".format(len(categorical)))
# Out:
# there are 0 discrete features
# there are 95 continous or numeric features
# there are 5 categorical features

# %%
categorical
# Out:
# ['x34', 'x35', 'x45', 'x68', 'x93']

# %%
data[categorical].nunique()
# Out:
# x34    10
# x35     8
# x45    10
# x68    12
# x93     3
# dtype: int64

# %%
for ft in categorical:
    print( ft ,"   ", data[ft].unique() )
# Out:
# x34     ['Honda' 'volkswagon' 'ford' 'Toyota' 'bmw' 'chrystler' 'tesla' 'nissan'
#  nan 'mercades' 'chevrolet']
# x35     ['wed' 'wednesday' 'thurday' 'thur' 'friday' 'tuesday' 'monday' 'fri' nan]
# x45     ['0.0%' '-0.0%' '-0.02%' '0.01%' '0.02%' '0.03%' '-0.01%' '-0.03%'
#  '-0.04%' '0.04%' nan]
# x68     ['July' 'Jun' 'Aug' 'sept.' 'May' 'Apr' 'Oct' 'Mar' 'Dev' 'Nov' nan 'Feb'
#  'January']
# x93     ['asia' 'america' 'euorpe' nan]

# %%
data['x35'] = data['x35'].replace('wed','wednesday' )
data['x35'] = data['x35'].replace('thur','thursday')
data['x35'] = data['x35'].replace('thurday','thursday' )
data['x35'] = data['x35'].replace('fri','friday')
data['x68'] = data['x68'].replace('Dev','Dec')
data['x93'] = data['x93'].replace('euorpe','europe')

# %%
for ft in categorical:
    print( ft ,"   ", data[ft].unique() )
# Out:
# x34     ['Honda' 'volkswagon' 'ford' 'Toyota' 'bmw' 'chrystler' 'tesla' 'nissan'
#  nan 'mercades' 'chevrolet']
# x35     ['wednesday' 'thursday' 'friday' 'tuesday' 'monday' nan]
# x45     ['0.0%' '-0.0%' '-0.02%' '0.01%' '0.02%' '0.03%' '-0.01%' '-0.03%'
#  '-0.04%' '0.04%' nan]
# x68     ['July' 'Jun' 'Aug' 'sept.' 'May' 'Apr' 'Oct' 'Mar' 'Dec' 'Nov' nan 'Feb'
#  'January']
# x93     ['asia' 'america' 'europe' nan]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Columns: 101 entries, x0 to y
# dtypes: float64(95), int64(1), object(5)
# memory usage: 30.8+ MB

# %%
#### split the data 
X_train, X_test, y_train, y_test = train_test_split(
data.drop('y',axis=1), ### predictors 
data['y'] ,      ### target
test_size=0.1,
    random_state =0
)

# %%
for ft in categorical:
    print( ft ,"   ", X_train[ft].unique() )
# Out:
# x34     ['bmw' 'Honda' 'Toyota' 'tesla' 'chrystler' 'volkswagon' 'nissan' 'ford'
#  'mercades' 'chevrolet' nan]
# x35     ['thursday' 'wednesday' 'friday' 'tuesday' 'monday' nan]
# x45     ['0.01%' '-0.01%' '0.0%' '-0.0%' '-0.02%' '0.03%' '0.02%' '-0.03%' nan
#  '-0.04%' '0.04%']
# x68     ['May' 'Apr' 'July' 'sept.' nan 'Aug' 'Jun' 'Dec' 'Oct' 'Nov' 'Mar' 'Feb'
#  'January']
# x93     ['asia' 'america' 'europe' nan]

# %%
data.isnull().mean().sort_values(ascending= False)
# Out:
# x85    0.000375
# x18    0.000350
# x65    0.000350
# x13    0.000350
# x96    0.000325
#          ...
# x88    0.000075
# x43    0.000050
# x83    0.000050
# x91    0.000050
# y      0.000000
# Length: 101, dtype: float64

# %%
print(data.shape)

prob_df = data.groupby(['x93'])['y'].mean()
prob_df
# Out:
# (40000, 101)
# x93
# america    0.210627
# asia       0.201710
# europe     0.196078
# Name: y, dtype: float64

# %%
fe_seq=Pipeline([
    
    ### IMPUTE NUMERIC ########
    ('imputer_num',
    mdi.ArbitraryNumberImputer(arbitrary_number= -100,variables = contin)),
    ##### IMPUTE CATEGORICAL #######
    ('imputer_cat',
    mdi.CategoricalVariableImputer(variables=categorical)),
    ##### REMOVE OUTLIERS##############
    ('outlier_rem',Winsorizer(distribution='skewed',
                             tail='both',
                             fold=2.0,
                             variables=contin)),
    ####### REMOVE RARE LABELS ###########
    ('encoder_rare_label',
     ce.RareLabelCategoricalEncoder(tol=0.02,
                                   n_categories=5,
                                   variables=categorical)),
     ##########  ENCODE CATEGORICAL VARIABLES ##########
     #('categorical_encoder',
     #ce.OrdinalCategoricalEncoder(encoding_method='ordered',
     #                            variables=categorical)),
     ########### ENCODE CATEGORICAL VARIABLES ##############
    ('categorical_encoder',
     WoERatioCategoricalEncoder(encoding_method='woe', variables = categorical)
    )
    #################  BIN NUMERICAL VARIABLES ##################
    #('BinDTE',
     # DecisionTreeDiscretiser(variables=contin,regression=False)),
     
     ###################### model is xgb
      #('xgb', XGBClassifier(max_depth=4,learning_rate=0.01))   
])

# %%
fe_seq.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('imputer_num',
#                  ArbitraryNumberImputer(arbitrary_number=-100,
#                                         variables=['x0', 'x1', 'x2', 'x3', 'x4',
#                                                    'x5', 'x6', 'x7', 'x8', 'x9',
#                                                    'x10', 'x11', 'x12', 'x13',
#                                                    'x14', 'x15', 'x16', 'x17',
#                                                    'x18', 'x19', 'x20', 'x21',
#                                                    'x22', 'x23', 'x24', 'x25',
#                                                    'x26', 'x27', 'x28', 'x29', ...])),
#                 ('imputer_cat',
#                  CategoricalVariableImputer(variables=['x34', 'x35', 'x45',
#                                                        'x6...
#                                        'x13', 'x14', 'x15', 'x16', 'x17', 'x18',
#                                        'x19', 'x20', 'x21', 'x22', 'x23', 'x24',
#                                        'x25', 'x26', 'x27', 'x28', 'x29', ...])),
#                 ('encoder_rare_label',
#                  RareLabelCategoricalEncoder(n_categories=5, tol=0.02,
#                                              variables=['x34', 'x35', 'x45',
#                                                         'x68', 'x93'])),
#                 ('categorical_encoder',
#                  WoERatioCategoricalEncoder(encoding_method='woe',
#                                             variables=['x34', 'x35', 'x45',
#                                                        'x68', 'x93']))],
#          verbose=False)

# %%
fe_seq.named_steps
# Out:
# {'imputer_num': ArbitraryNumberImputer(arbitrary_number=-100,
#                         variables=['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6',
#                                    'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13',
#                                    'x14', 'x15', 'x16', 'x17', 'x18', 'x19',
#                                    'x20', 'x21', 'x22', 'x23', 'x24', 'x25',
#                                    'x26', 'x27', 'x28', 'x29', ...]),
#  'imputer_cat': CategoricalVariableImputer(variables=['x34', 'x35', 'x45', 'x68', 'x93']),
#  'outlier_rem': Winsorizer(distribution='skewed', fold=2.0, tail='both',
#             variables=['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8',
#                        'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16',
#                        'x17', 'x18', 'x19', 'x20', 'x21', 'x22', 'x23', 'x24',
#                        'x25', 'x26', 'x27', 'x28', 'x29', ...]),
#  'encoder_rare_label': RareLabelCategoricalEncoder(n_categories=5, tol=0.02,
#                              variables=['x34', 'x35', 'x45', 'x68', 'x93']),
#  'categorical_encoder': WoERatioCategoricalEncoder(encoding_method='woe',
#                             variables=['x34', 'x35', 'x45', 'x68', 'x93'])}

# %% [markdown]
# # ----------------- FEATURE SELECTION ----------------------------

# %%
X_train_fe = fe_seq.transform(X_train)
X_test_fe = fe_seq.transform(X_test)

print (X_train_fe.shape)
print(X_test_fe.shape)

type(X_train_fe)
# Out:
# (36000, 100)
# (4000, 100)
# pandas.core.frame.DataFrame

# %%
sel = VarianceThreshold(threshold=0.05)  # 0.1 indicates 99% of observations approximately
 
sel.fit(X_train_fe)  # fit finds the features with low variance
 
print("We are keeping total of {} features".format(sum(sel.get_support())) )

features_to_keep = X_train_fe.columns[sel.get_support()]  ### put the low variance features in a list


X_train_fe = sel.transform(X_train_fe)
X_test_fe = sel.transform(X_test_fe)

X_train_fe= pd.DataFrame(X_train_fe)
X_train_fe.columns = features_to_keep
 
X_test_fe= pd.DataFrame(X_test_fe)
X_test_fe.columns = features_to_keep
# Out:
# We are keeping total of 95 features

# %%
X_train_fe.head(3)
# Out:
#            x0        x1         x2         x3         x4         x5        x6  \
# 0  169.641904  0.088613 -59.990029  -4.151638   1.843480   4.227388 -1.532988
# 1   -3.526688 -0.268400  37.806397 -17.839056 -25.652887 -12.467933 -0.251797
# 2  161.642454 -0.444992  -7.470376  16.232460 -31.172866 -29.116958  0.820005
#
#           x7         x8        x9  ...        x89        x90       x91  \
# 0  -0.853600 -29.899352 -6.527814  ...  -6.414780  80.894934  1.093422
# 1  -6.662036  30.391301  5.768376  ... -16.473919 -44.267839  1.389046
# 2 -13.101334  23.864927  9.193680  ...  -4.270320  79.699387  0.423168
#
#         x92       x94        x95        x96        x97       x98       x99
# 0 -0.567839 -3.891708 -17.854918   3.092545  -9.385536  0.419702 -1.228195
# 1 -0.535372 -2.130634  20.987745  -8.050412 -18.010767  0.703264  3.347602
# 2 -1.628482 -6.364589  21.129760 -20.371733   0.433292 -0.922341 -8.360633
#
# [3 rows x 95 columns]

# %%
#### remove correlated features 
# find and remove correlated features
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

corr_features = correlation(X_train_fe, 0.9)
print('correlated features: ', len(set(corr_features)) )

X_train_fe.drop(labels=corr_features, axis=1, inplace=True)
X_test_fe.drop(labels=corr_features, axis=1, inplace=True)

X_train_fe = pd.DataFrame(X_train_fe)
X_test_fe = pd.DataFrame(X_test_fe)

X_train_fe.shape, X_test_fe.shape
# Out:
# correlated features:  0
# ((36000, 95), (4000, 95))

# %%
######## Feature selection with random forest 
sel_ = SelectFromModel(RandomForestClassifier(max_depth = 4 , n_estimators=300 , random_state=0))
sel_.fit(X_train_fe, y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(bootstrap=True,
#                                                  class_weight=None,
#                                                  criterion='gini', max_depth=4,
#                                                  max_features='auto',
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=300, n_jobs=None,
#                                                  oob_score=False,
#                                                  random_state=0, verbose=0,
#                                                  warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
# sklearn will select those features which importance values
# are greater than the mean of all the coefficients.
sel_.get_support()
# Out:
# array([False,  True,  True,  True, False,  True, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False,  True,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False,  True,  True, False, False,  True, False, False,
#        False, False,  True,  True, False, False, False, False,  True,
#        False,  True, False, False, False, False,  True, False, False,
#         True, False,  True,  True, False,  True,  True, False,  True,
#        False, False,  True, False, False, False, False,  True, False,
#         True, False, False, False, False, False, False, False, False,
#        False,  True,  True, False,  True])

# %%
selected_feat = X_train_fe.columns[(sel_.get_support())]
print(len(selected_feat) )

selected_feat
# Out:
# 28
# Index(['x1', 'x2', 'x3', 'x5', 'x10', 'x21', 'x22', 'x37', 'x40', 'x41', 'x44',
#        'x50', 'x51', 'x56', 'x58', 'x63', 'x66', 'x69', 'x70', 'x72', 'x73',
#        'x75', 'x78', 'x83', 'x85', 'x96', 'x97', 'x99'],
#       dtype='object')

# %%
X_train_fe =  X_train_fe[selected_feat]
X_test_fe =  X_test_fe[selected_feat]

print(type(X_train_fe))
print(type(X_test_fe))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
#model = XGBClassifier(max_depth=4,learning_rate=0.01)
model = CatBoostClassifier(max_depth=4,learning_rate=0.01)

model.fit(X_train_fe,y_train)
# Out:
# 0:	learn: 0.6876002	total: 167ms	remaining: 2m 46s
# 1:	learn: 0.6821042	total: 179ms	remaining: 1m 29s
# 2:	learn: 0.6773076	total: 191ms	remaining: 1m 3s
# 3:	learn: 0.6721560	total: 203ms	remaining: 50.6s
# 4:	learn: 0.6673186	total: 215ms	remaining: 42.9s
# 5:	learn: 0.6620110	total: 227ms	remaining: 37.7s
# 6:	learn: 0.6569184	total: 240ms	remaining: 34s
# 7:	learn: 0.6522135	total: 252ms	remaining: 31.2s
# 8:	learn: 0.6476014	total: 264ms	remaining: 29.1s
# 9:	learn: 0.6432540	total: 276ms	remaining: 27.4s
# 10:	learn: 0.6384598	total: 288ms	remaining: 25.9s
# 11:	learn: 0.6343397	total: 300ms	remaining: 24.7s
# 12:	learn: 0.6299898	total: 312ms	remaining: 23.7s
# 720:	learn: 0.3012142	total: 10s	remaining: 3.89s
# 721:	learn: 0.3010821	total: 10.1s	remaining: 3.87s
# 722:	learn: 0.3009667	total: 10.1s	remaining: 3.86s
# 723:	learn: 0.3008665	total: 10.1s	remaining: 3.84s
# 724:	learn: 0.3007681	total: 10.1s	remaining: 3.83s
# 725:	learn: 0.3006492	total: 10.1s	remaining: 3.81s
# 726:	learn: 0.3005352	total: 10.1s	remaining: 3.8s
# 727:	learn: 0.3004280	total: 10.1s	remaining: 3.79s
# 728:	learn: 0.3003012	total: 10.1s	remaining: 3.77s
# 729:	learn: 0.3001376	total: 10.2s	remaining: 3.76s
# 730:	learn: 0.2999959	total: 10.2s	remaining: 3.74s
# 731:	learn: 0.2998615	total: 10.2s	remaining: 3.73s
# 732:	learn: 0.2997404	total: 10.2s	remaining: 3.71s
# 733:	learn: 0.2996134	total: 10.2s	remaining: 3.7s
# 734:	learn: 0.2994772	total: 10.2s	remaining: 3.69s
# 735:	learn: 0.2993036	total: 10.2s	remaining: 3.67s
# 736:	learn: 0.2992123	total: 10.3s	remaining: 3.66s
# 737:	learn: 0.2991043	total: 10.3s	remaining: 3.64s
# 738:	learn: 0.2990102	total: 10.3s	remaining: 3.63s
# 739:	learn: 0.2988921	total: 10.3s	remaining: 3.62s
# 740:	learn: 0.2987840	total: 10.3s	remaining: 3.6s
# 741:	learn: 0.2986695	total: 10.3s	remaining: 3.59s
# 742:	learn: 0.2985799	total: 10.3s	remaining: 3.57s
# 743:	learn: 0.2984425	total: 10.3s	remaining: 3.56s
# 744:	learn: 0.2983495	total: 10.4s	remaining: 3.54s
# 745:	learn: 0.2982548	total: 10.4s	remaining: 3.53s
# 746:	learn: 0.2981714	total: 10.4s	remaining: 3.52s
# 747:	learn: 0.2980187	total: 10.4s	remaining: 3.5s
# 748:	learn: 0.2979242	total: 10.4s	remaining: 3.49s
# 749:	learn: 0.2978063	total: 10.4s	remaining: 3.47s
# 750:	learn: 0.2976537	total: 10.4s	remaining: 3.46s
# 751:	learn: 0.2975505	total: 10.4s	remaining: 3.44s
# 752:	learn: 0.2974382	total: 10.5s	remaining: 3.43s
# 753:	learn: 0.2973474	total: 10.5s	remaining: 3.41s
# 754:	learn: 0.2972412	total: 10.5s	remaining: 3.4s
# 755:	learn: 0.2971493	total: 10.5s	remaining: 3.39s
# 756:	learn: 0.2970344	total: 10.5s	remaining: 3.37s
# 757:	learn: 0.2969204	total: 10.5s	remaining: 3.36s
# 758:	learn: 0.2967971	total: 10.5s	remaining: 3.34s
# 759:	learn: 0.2967084	total: 10.5s	remaining: 3.33s
# 760:	learn: 0.2966188	total: 10.6s	remaining: 3.31s
# 761:	learn: 0.2965241	total: 10.6s	remaining: 3.3s
# 762:	learn: 0.2964288	total: 10.6s	remaining: 3.29s
# 763:	learn: 0.2963275	total: 10.6s	remaining: 3.27s
# 764:	learn: 0.2962136	total: 10.6s	remaining: 3.26s
# 765:	learn: 0.2961259	total: 10.6s	remaining: 3.25s
# 766:	learn: 0.2960008	total: 10.6s	remaining: 3.23s
# 862:	learn: 0.2862372	total: 12s	remaining: 1.9s
# 863:	learn: 0.2861596	total: 12s	remaining: 1.89s
# 864:	learn: 0.2860543	total: 12s	remaining: 1.88s
# 865:	learn: 0.2859649	total: 12s	remaining: 1.86s
# 866:	learn: 0.2858693	total: 12s	remaining: 1.85s
# 867:	learn: 0.2857836	total: 12.1s	remaining: 1.83s
# 868:	learn: 0.2856568	total: 12.1s	remaining: 1.82s
# 869:	learn: 0.2855616	total: 12.1s	remaining: 1.81s
# 870:	learn: 0.2854420	total: 12.1s	remaining: 1.79s
# 871:	learn: 0.2853571	total: 12.1s	remaining: 1.78s
# 872:	learn: 0.2852733	total: 12.1s	remaining: 1.76s
# 873:	learn: 0.2851841	total: 12.1s	remaining: 1.75s
# 874:	learn: 0.2850902	total: 12.1s	remaining: 1.74s
# 875:	learn: 0.2849877	total: 12.2s	remaining: 1.72s
# 876:	learn: 0.2848807	total: 12.2s	remaining: 1.71s
# 877:	learn: 0.2847796	total: 12.2s	remaining: 1.69s
# 878:	learn: 0.2846423	total: 12.2s	remaining: 1.68s
# 879:	learn: 0.2845485	total: 12.2s	remaining: 1.67s
# 880:	learn: 0.2844541	total: 12.2s	remaining: 1.65s
# 881:	learn: 0.2843651	total: 12.2s	remaining: 1.64s
# 882:	learn: 0.2842673	total: 12.2s	remaining: 1.62s
# 883:	learn: 0.2841864	total: 12.3s	remaining: 1.61s
# 884:	learn: 0.2840813	total: 12.3s	remaining: 1.59s
# 885:	learn: 0.2839861	total: 12.3s	remaining: 1.58s
# 886:	learn: 0.2839098	total: 12.3s	remaining: 1.57s
# 887:	learn: 0.2838292	total: 12.3s	remaining: 1.55s
# 888:	learn: 0.2837207	total: 12.3s	remaining: 1.54s
# 889:	learn: 0.2836218	total: 12.3s	remaining: 1.52s
# 890:	learn: 0.2835198	total: 12.3s	remaining: 1.51s
# 891:	learn: 0.2834283	total: 12.4s	remaining: 1.5s
# 892:	learn: 0.2833292	total: 12.4s	remaining: 1.48s
# 893:	learn: 0.2832414	total: 12.4s	remaining: 1.47s
# 894:	learn: 0.2831387	total: 12.4s	remaining: 1.46s
# 895:	learn: 0.2830242	total: 12.4s	remaining: 1.44s
# 896:	learn: 0.2829275	total: 12.4s	remaining: 1.43s
# 897:	learn: 0.2828224	total: 12.4s	remaining: 1.41s
# 898:	learn: 0.2827603	total: 12.5s	remaining: 1.4s
# 899:	learn: 0.2826556	total: 12.5s	remaining: 1.39s
# 900:	learn: 0.2825646	total: 12.5s	remaining: 1.37s
# 901:	learn: 0.2824665	total: 12.5s	remaining: 1.36s
# 902:	learn: 0.2823971	total: 12.5s	remaining: 1.34s
# 903:	learn: 0.2822888	total: 12.5s	remaining: 1.33s
# 904:	learn: 0.2821649	total: 12.6s	remaining: 1.32s
# 905:	learn: 0.2820868	total: 12.6s	remaining: 1.3s
# 906:	learn: 0.2820022	total: 12.6s	remaining: 1.29s
# 907:	learn: 0.2819213	total: 12.6s	remaining: 1.28s
# 908:	learn: 0.2818511	total: 12.6s	remaining: 1.26s
